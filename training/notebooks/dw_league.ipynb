# %% [markdown]
# # DEADWEIGHT league training (Colab stub)
# Mirrors BRAWLPIT's notebook. NOT run in the authoring sandbox -- verify on Colab.

# %%
import getpass, os
os.environ['GITHUB_TOKEN'] = getpass.getpass('GitHub token (repo read)')
# !git clone https://x-access-token:$GITHUB_TOKEN@github.com/emilyspringerton/DEADWEIGHT.git
# %cd DEADWEIGHT

# %%
# !pip -q install gymnasium stable-baselines3 sb3-contrib
# !scripts/build.sh   # builds build/dw_server (gcc)

# %%
# %cd training
# !python3 -m unittest test_dw_rules test_dw_env test_dw_train test_rl_league test_rl_registry

# %%
# smoke: dry run against the fake server
# !python3 dw_train.py --dry-run --generations 2 --episodes 10 --league-dir /content/league_smoke

# %%
# real training; set IDUNA_AGENT_SECRET (DEADWEIGHT-RL) to push checkpoints to the registry
import getpass, os
os.environ['IDUNA_AGENT_SECRET'] = getpass.getpass('DEADWEIGHT-RL secret (blank = local only)')
# !python3 dw_train.py --server-bin ../build/dw_server --generations 10 --timesteps 4096 --league-dir /content/league --source-location colab

# %%
from rl_league import LeagueManager
for m in sorted(LeagueManager('/content/league').all_members(), key=lambda m: (m.generation, m.role)):
    print(m.generation, m.role, m.id)

# %%
# !zip -r /content/league.zip /content/league
from google.colab import files; files.download('/content/league.zip')
